# %%
import json

with open('wikiData_trans.json', 'r') as f:
    wiki_data = json.loads(f.read())

# %%
import pandas as pd

data = pd.read_json('wikiData.json')

print(data)
# Out:
#                                                                a  \
# morfology                                         a (indefinite)
# pronunciation                                    {'IPA': '/eɪ/'}
# meanings       [{'class': 'article', 'examples': ['I've seen ...
#
#                                                             able  \
# morfology           able (comparative abler, superlative ablest)
# pronunciation                     {'US': '/ˈeɪ.bl̩/, /ˈeɪ.bəl/'}
# meanings       [{'class': 'adjective', 'examples': ['He was b...
#
#                                                            about  \
# morfology                                                  about
# pronunciation                               {'IPA': '/əˈ baʊt/'}
# meanings       [{'class': 'preposition', 'examples': ['to be ...
#
#                                                         accident  \
# morfology      accident (countable and uncountable, plural ac...
# ...
